# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Admin/Desktop/dream11ml/data/processed/processed_data.csv')
print("Processed data loaded successfully!")
# Out:
# Processed data loaded successfully!

# %%
print("\nData Info:")
df.info()

print("\nDescriptive Statistics:")
print(df.describe())
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19778 entries, 0 to 19777
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   match_id        19778 non-null  int64
#  1   team            19778 non-null  object
#  2   player_name     19778 non-null  object
#  3   runs            19778 non-null  float64
#  4   wickets         19778 non-null  float64
#  5   fours           19778 non-null  int64
#  6   sixes           19778 non-null  int64
#  7   catches         19778 non-null  int64
#  8   fantasy_points  19778 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.4+ MB
#
# Descriptive Statistics:
#            match_id          runs       wickets    fours    sixes  \
# count  1.977800e+04  19778.000000  19778.000000  19778.0  19778.0
# mean   8.782062e+05     14.298210      0.529882      0.0      0.0
# std    3.499569e+05      2.860915      0.222864      0.0      0.0
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['fantasy_points'], bins=30, kde=True)
plt.title('Distribution of Fantasy Points')
plt.xlabel('Fantasy Points')
plt.ylabel('Count')
plt.show()

# %%
key_features = ['runs', 'wickets', 'catches', 'fantasy_points']
sns.pairplot(df[key_features])
plt.suptitle('Pair Plot of Key Features vs. Fantasy Points', y=1.02)
plt.show()

# %%
correlation_matrix = df[key_features].corr()

# Plot a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
